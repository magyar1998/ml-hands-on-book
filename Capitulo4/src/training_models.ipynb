# %% [markdown]
# LINER REGRESSION

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 2 * np.random.rand(100, 1)
y = 4 + 3* x + np.random.rand(100,1)

# %%
plt.scatter(x, y)

# %% [markdown]
# MÉTODO DO MINIMOS QUADRADOS

# %%
X_b = np.c_[np.ones((100, 1)), x]

# %%
X_b.T.dot(X_b)
# Out:
# array([[100.        ,  95.44014011],
#        [ 95.44014011, 120.30987875]])

# %%
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best, theta_best[0, 0], theta_best[1,0]
# Out:
# (array([[4.46075251],
#         [3.05168872]]),
#  4.460752506470896,
#  3.0516887181788044)

# %%
x_new = np.array([[0], [2]])
x_new_b = np.c_[np.ones((2, 1)), x_new]

# %%
y_pred = x_new_b.dot(theta_best)
y_pred
# Out:
# array([[ 4.46075251],
#        [10.56412994]])

# %%
plt.plot(x_new, y_pred, "r-")
plt.plot(x, y, ".", color = "black")
plt.axis([0, 2, 0 ,15])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()
linear_reg.fit(x, y)
pred = linear_reg.predict(x)

linear_reg.coef_, linear_reg.intercept_

print(linear_reg.predict(x_new))
# Out:
# [[ 4.46075251]
#  [10.56412994]]

# %%
mae = []

for i in range(0, len(y)):
    mae_value = np.abs(y[i] - pred[i])
    mae.append(mae_value[0])

# %%
plt.scatter(x, mae)

# %% [markdown]
# GRADIENTE DESCENDENTE

# %%
eta = 0.1 # taxa de aprendizado
n_iterations = 1000
m = 100
theta = np.random.randn(2,1) # inicialização aleatória
for iteration in range(n_iterations):
 gradients = 2/m * X_b.T.dot(X_b.dot(theta) - y)
 theta = theta - eta * gradients
